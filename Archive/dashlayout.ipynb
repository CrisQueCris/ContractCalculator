# %%
import JupyterDash
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [11], in <cell line: 9>()
#       7 from dash import html
#       8 from dash.dependencies import Input, Output
# ----> 9 import JupyterDash
#
# ModuleNotFoundError: No module named 'JupyterDash'

# %%
app = dash.Dash(__name__)

# %%
##Import and clean data
future_df = pd.read_csv('Data/future_df')
future_df
# Out:
#    Unnamed: 0  kontrakt   price absolut_inc perc_inc date_fullfillment  \
# 0           0  Mai 2022  351.80        3,15  +0,90 %        2022-05-23
# 1           1  Jul 2022  347.60        3,15  +0,91 %        2022-07-07
# 2           2  Nov 2022  336.30        3,15  +0,95 %        2022-11-23
# 3           3  Jan 2023  338.70        3,55  +1,06 %        2023-01-23
# 4           4  Mär 2023  340.40        3,45  +1,02 %        2023-03-23
# 5           5  Mai 2023  342.30        3,35  +0,99 %        2023-05-23
# 6           6  Jul 2023  316.85        4,35  +1,39 %        2023-07-07
# 7           7  Nov 2023  286.80        5,35  +1,90 %        2023-11-23
# 8           8  Jan 2024  287.75        5,35  +1,89 %        2024-01-23
# 9           9  Mär 2024  289.25        5,35  +1,88 %        2024-03-22
#
#    date_price currency  commodity_id
# 0  2022-05-15      GBP             2
# 1  2022-05-15      GBP             2
# 2  2022-05-15      GBP             2
# ...
